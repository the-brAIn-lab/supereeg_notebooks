# %% [markdown]
# # Building a brain object
#
# Brain objects are supereeg’s fundamental data structure for a single subject’s ECoG data. To create one at minimum you’ll need a matrix of neural recordings (time samples by electrodes), electrode locations, and a sample rate. Additionally, you can include information about separate recording sessions and store custom meta data. In this tutorial, we’ll build a brain object from scratch and get familiar with some of the methods.

# %% [markdown]
# # Load in the required libraries

# %%
import supereeg as se
import numpy as np
import warnings
import os
import gzip
from nibabel.testing import data_path
example_ni1 = os.path.join(data_path, 'example4d.nii.gz')
warnings.simplefilter("ignore")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Simulate some data
#
# First, we’ll use supereeg’s built in simulation functions to simulate some data and electrodes. By default, the simulate_data function will return a 1000 samples by 10 electrodes matrix, but you can specify the number of time samples with n_samples and the number of electrodes with n_elecs. If you want further information on simulating data, check out the simulate tutorial!

# %%
# simulate some data
bo_data = se.simulate_bo(n_samples=1000, sessions=2, n_elecs=10)

# plot it
bo_data.plot_data()

# get just data
data = bo_data.get_data()

# %% [markdown]
# We’ll also simulate some electrode locations

# %%
locs = se.simulate_locations()
print(locs)
# Out:
#     x   y   z
# 0 -48 -19 -47
# 1 -27 -16  40
# 2 -23  49  39
# 3  -8 -27  -4
# 4  -4 -43  30
# 5  14 -42   3
# 6  17   3 -27
# 7  27  48  -2
# 8  38 -11 -22
# 9  39  -7  20

# %% [markdown]
# # Creating a brain object
#
# To construct a new brain objects, simply pass the data and locations to the Brain class like this:

# %%
bo = se.Brain(data=data, locs=locs, sample_rate=100)

# %% [markdown]
# To view a summary of the contents of the brain object, you can call the info function:

# %%
bo.info()
# Out:
# Number of electrodes: 10
# Recording time in seconds: [10.]
# Sample Rate in Hz: [100]
# Number of sessions: 1
# Date created: Thu Jan 16 01:27:17 2025
# Meta data: {}

# %% [markdown]
# Optionally, you can pass a sessions parameter, which is can be a numpy array or list the length of your data with a unique identifier for each session. For example:

# %%
sessions = np.array([1]*(data.shape[0]//2)+[2]*(data.shape[0]//2))
bo = se.Brain(data=data, locs=locs, sample_rate=1000, sessions=sessions)
bo.info()
# Out:
# Number of electrodes: 10
# Recording time in seconds: [0.5 0.5]
# Sample Rate in Hz: [1000, 1000]
# Number of sessions: 2
# Date created: Thu Jan 16 01:27:17 2025
# Meta data: {}

# %% [markdown]
# You can also add custom meta data to the brain object to help keep track of its contents. meta is a dictionary comprised of whatever you want:

# %%
meta = {
    'subjectID' : '123',
    'Investigator' : 'Andy',
    'Hospital' : 'DHMC'
}
bo = se.Brain(data=data, locs=locs, sample_rate=1000, sessions=sessions, meta=meta)
bo.info()
# Out:
# Number of electrodes: 10
# Recording time in seconds: [0.5 0.5]
# Sample Rate in Hz: [1000, 1000]
# Number of sessions: 2
# Date created: Thu Jan 16 01:27:17 2025
# Meta data: {'subjectID': '123', 'Investigator': 'Andy', 'Hospital': 'DHMC'}

# %% [markdown]
# # Initialize brain objects
#
# Brain objects can be initialized by passing any of the following to the Brain class instance initialization function:
#
# - A path to a saved Brain object (ending in .bo)
# - An existing Brain object (this creates a copy of the object)
# - A path to or instance of any other supported toolbox type (Model objects or .mo files, or Nifti objects or .nii files)
#
# In addition, Brain objects may be created via load by specifying return_type='bo'.
#
# For example:

# %%
with gzip.open(example_ni1) as f:
    nii_bo = se.Brain(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 with gzip.open(example_ni1) as f:
# ----> 2     nii_bo = se.Brain(f)
#
# File ~/Documents/supereeg/supereeg/supereeg/brain.py:215, in Brain.__init__(self, data, locs, sessions, sample_rate, meta, date_created, label, kurtosis, kurtosis_threshold, minimum_voxel_size, maximum_voxel_size, filter, affine)
#     213     self.kurtosis = kurtosis
#     214 else:
# --> 215     self.kurtosis = _kurt_vals(self)
#     216 self.kurtosis_threshold = kurtosis_threshold
#     217 self.filter=filter
#
# File ~/Documents/supereeg/supereeg/supereeg/helpers.py:208, in _kurt_vals(bo)
#     193 """
#     194 Function that calculates maximum kurtosis values for each channel
#     195
#    (...)
#     205
#     206 """
#     207 sessions = bo.sessions.unique()
# --> 208 results = list(map(lambda s: kurtosis(bo.data[(s==bo.sessions).values]), sessions))
#     209 return np.max(np.vstack(results), axis=0)
#
# File ~/Documents/supereeg/supereeg/supereeg/helpers.py:208, in _kurt_vals.<locals>.<lambda>(s)
#     193 """
#     194 Function that calculates maximum kurtosis values for each channel
#     195
#    (...)
#     205
#     206 """
#     207 sessions = bo.sessions.unique()
# --> 208 results = list(map(lambda s: kurtosis(bo.data[(s==bo.sessions).values]), sessions))
#     209 return np.max(np.vstack(results), axis=0)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:563, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     560     contains_nan = False  # behave like there are no NaNs
#     562 if vectorized and not contains_nan and not sentinel:
# --> 563     res = hypotest_fun_out(*samples, axis=axis, **kwds)
#     564     res = result_to_tuple(res)
#     565     res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/scipy/stats/_stats_py.py:1281, in kurtosis(a, axis, fisher, bias, nan_policy)
#    1278     return mstats_basic.kurtosis(a, axis, fisher, bias)
#    1280 n = a.shape[axis]
# -> 1281 mean = a.mean(axis, keepdims=True)
#    1282 m2 = _moment(a, 2, axis, mean=mean)
#    1283 m4 = _moment(a, 4, axis, mean=mean)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/numpy/core/_methods.py:121, in _mean(a, axis, dtype, out, keepdims, where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
# --> 121         ret = um.true_divide(
#     122                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     123     if is_float16_result and out is None:
#     124         ret = arr.dtype.type(ret)
#
# TypeError: unsupported operand type(s) for /: 'bytes' and 'int'

# %% [markdown]
# Or:

# %%
nii_bo = se.load('example_ni1', return_type='bo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nii_bo = se.load('example_ni1', return_type='bo')
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:110, in load(fname, vox_size, return_type, sample_inds, loc_inds, field)
#     108     data = _load_example(fname, datadict[fname], sample_inds, loc_inds, field)
#     109 else:
# --> 110     data = _load_from_path(fname, sample_inds, loc_inds, field)
#     111 if field is None:
#     112     return _convert(data, return_type, vox_size)
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:218, in _load_from_path(fpath, sample_inds, loc_inds, field)
#     216     return Nifti(fpath)
#     217 else:
# --> 218     raise ValueError("Filetype not recognized. Must be .bo, .mo or .nii.")
#
# ValueError: Filetype not recognized. Must be .bo, .mo or .nii.

# %% [markdown]
# Another feature, which can be particularly useful when working with large files, is loading only a subfield by specifiying field. For example, if you only want to load locations:

# %%
bo_locs = se.load('example_data', field='locs')

# %% [markdown]
# # The structure of a brain object
#
# Inside the brain object, the ECoG data are stored in a Pandas DataFrame that can be accessed with the get_data function:

# %%
bo.get_data().head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.345944  0.553480  0.156498  0.561233  0.057039  0.640744  0.785934
# 1 -0.700963 -0.881538 -0.595310 -0.875498 -1.452550 -1.193997 -0.912997
# 2 -1.429732 -0.844867 -1.121776 -0.343427 -0.022371 -1.005917 -0.442732
# 3  1.317233  1.272027  1.252572  0.887291  1.453519  0.766107  0.646922
# 4 -0.227095 -0.949091 -0.616452 -0.405545 -0.774518 -0.196553 -0.078474
#
#           7         8         9
# 0  0.641539  0.536225  0.352250
# 1 -1.096833 -0.516904 -0.625345
# 2 -0.267224  0.175048 -1.054384
# 3  0.889926  0.955378  0.202356
# 4 -0.411012 -1.138648 -0.795502

# %% [markdown]
# Similarly, the electrode locations are stored as a Pandas DataFrame, and can be retrieved using the get_locs method:

# %%
bo.get_locs().head()
# Out:
#     x   y   z
# 0 -48 -19 -47
# 1 -27 -16  40
# 2 -23  49  39
# 3  -8 -27  -4
# 4  -4 -43  30

# %% [markdown]
# Brain objects are iterable, so you index a brain object like this:

# %%
#return first time sample
bo[0]
#return first 3 time samples
bo[:3]
#return first electrode
bo[:, 0]
#returns first 3 timesamples/elecs
bo_i = bo[:3, :3]
bo_i.get_data()
# Out:
#           0         1         2
# 0  0.345944  0.553480  0.156498
# 1 -0.700963 -0.881538 -0.595310
# 2 -1.429732 -0.844867 -1.121776

# %% [markdown]
# You can also pass a list of indices for either times (sample numbers) or locs to the get_slice method and return a subset of the brain object.

# %%
bo_s = bo.get_slice(sample_inds=[0,1,2], loc_inds=[0,1,2])
bo_s.get_data()
# Out:
#           0         1         2
# 0  0.345944  0.553480  0.156498
# 1 -0.700963 -0.881538 -0.595310
# 2 -1.429732 -0.844867 -1.121776

# %% [markdown]
# You can resample your data by specifying a new sample rate

# %%
bo.resample(64)
bo.info()
# Out:
# Number of electrodes: 10
# Recording time in seconds: [0.5 0.5]
# Sample Rate in Hz: [64, 64]
# Number of sessions: 2
# Date created: Thu Jan 16 01:27:17 2025
# Meta data: {'subjectID': '123', 'Investigator': 'Andy', 'Hospital': 'DHMC'}

# %% [markdown]
# You can also plot both the data and the electrode locations:

# %%
bo.plot_data()

# %%
bo.plot_locs()

# %% [markdown]
# The other pieces of the brain object are listed below:

# %%
# array of session identifiers for each timepoint
sessions = bo.sessions

# number of sessions
n_sessions = bo.n_sessions

# sample rate
sample_rate = bo.sample_rate

# number of electrodes
n_elecs = bo.n_elecs

# length of each recording session in seconds
n_seconds = bo.dur

# the date and time that the bo was created
date_created = bo.date_created

# kurtosis of each electrode
kurtosis = bo.kurtosis

# meta data
meta = bo.meta

# label delinieating observed and reconstructed locations
label = bo.label

# %% [markdown]
# # Brain object methods
#
# There are a few other useful methods on a brain object

# %% [markdown]
# ## bo.info()
#
# This method will give you a summary of the brain object:

# %%
bo.info()
# Out:
# Number of electrodes: 10
# Recording time in seconds: [0.5 0.5]
# Sample Rate in Hz: [64, 64]
# Number of sessions: 2
# Date created: Thu Jan 16 01:27:17 2025
# Meta data: {'subjectID': '123', 'Investigator': 'Andy', 'Hospital': 'DHMC'}

# %% [markdown]
# ## bo.apply_filter()
#
# This method will return a filtered copy of the brain object.

# %%
bo_f = bo.apply_filter()

# %% [markdown]
# ## bo.get_data()

# %%
data_array = bo.get_data()

# %% [markdown]
# ## bo.get_zscore_data()
#
# This method will return a numpy array of the zscored data:

# %%
zdata_array = bo.get_zscore_data()

# %% [markdown]
# ## bo.get_locs()
#
# This method will return a numpy array of the electrode locations:

# %%
locs = bo.get_locs()

# %% [markdown]
# ## bo.get_slice()
#
# This method allows you to slice out time and locations from the brain object, and returns a brain object. This can occur in place if you set the flag inplace=True.

# %%
bo_slice = bo.get_slice(sample_inds=None, loc_inds=None, inplace=False)

# %% [markdown]
# ## bo.resample()
#
# This method allows you resample a brain object in place.

# %%
bo.resample(resample_rate=None)

# %% [markdown]
# ## bo.plot_data()
#
# This method normalizes and plots data from brain object:

# %%
bo.plot_data()

# %% [markdown]
# ## bo.plot_locs()
#
# This method plots electrode locations from brain object:

# %%
bo_f = se.load('example_filter')

# %%
bo_f.plot_locs()

# %% [markdown]
# ## bo.to_nii()
#
# This method converts the brain object into supereeg’s nifti class (a subclass of the nibabel nifti class). If filepath is specified, the nifti file will be saved. You can also specify a nifti template with the template argument. If no template is specified, it will use the gray matter masked MNI 152 brain downsampled to 6mm.

# %%
# convert to nifti
nii = bo.to_nii(template='gray', vox_size=6)

# plot first timepoint
nii.plot_glass_brain()

# save the file
# nii = bo.to_nii(filepath='~/Documents/supereeg/brain_object')

# specify a template and resolution
# nii = bo.to_nii(template='/path/to/nifti/file.nii', vox_size=20)

# %% [markdown]
# ## bo.save(fname='something')
#
# This method will save the brain object to the specified file location. The data will be saved as a ‘bo’ file, which is a dictionary containing the elements of a brain object saved in the hd5 format using deepdish.

# %%
bo.save(fname='brain_object')
