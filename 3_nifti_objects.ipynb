# %% [markdown]
# # Nifti objects data type
#
# Another option for plotting and importing/exporting data is using the Nifti objects. Nifti objects are a subclass of the neuroimaging format Nibabel Nifti1Image, which is a file that generally has the extension “.nii” or “.nii.gz”. This allows the user to use our methods with the Nifti class but also use other functionality such as Nibabel and Nilearn methods.

# %% [markdown]
# # Load in the required libraries

# %%
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline
import supereeg as se
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# First, let’s load in an example nifti file, example_nifti:

# %%
nii = se.load('example_nifti')
# Out:
# sizeof_hdr should be 348; set sizeof_hdr to 348
# data code 26996 not recognized; not attempting fix
# sizeof_hdr should be 348; set sizeof_hdr to 348
# data code 26996 not recognized; not attempting fix
# ---------------------------------------------------------------------------
# HeaderDataError                           Traceback (most recent call last)
# File ~/Documents/supereeg/supereeg/supereeg/load.py:161, in _load_example(fname, fileid, sample_inds, loc_inds, field)
#     160 try:
# --> 161     data = _load_from_cache(fname, fileid[1], sample_inds, loc_inds, field)
#     162 except:
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:247, in _load_from_cache(fname, ftype, sample_inds, loc_inds, field)
#     246 elif ftype == 'nii':
# --> 247     return Nifti(fullpath)
#     248 elif ftype == 'locs':
#
# File ~/Documents/supereeg/supereeg/supereeg/nifti.py:53, in Nifti.__init__(self, data, affine, **kwargs)
#      52 else:
# ---> 53     image = Nifti1Image.load(data)
#      54     super(Nifti, self).__init__(image.dataobj, image.affine)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/dataobj_images.py:504, in DataobjImage.from_filename(klass, filename, mmap, keep_file_open)
#     503 file_map = klass.filespec_to_file_map(filename)
# --> 504 return klass.from_file_map(file_map, mmap=mmap, keep_file_open=keep_file_open)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/analyze.py:963, in AnalyzeImage.from_file_map(klass, file_map, mmap, keep_file_open)
#     962 with hdr_fh.get_prepare_fileobj(mode='rb') as hdrf:
# --> 963     header = klass.header_class.from_fileobj(hdrf)
#     964 hdr_copy = header.copy()
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/nifti1.py:863, in Nifti1Header.from_fileobj(klass, fileobj, endianness, check)
#     862 raw_str = fileobj.read(klass.template_dtype.itemsize)
# --> 863 hdr = klass(raw_str, endianness, check)
#     864 # Read next 4 bytes to see if we have extensions.  The nifti standard
#     865 # has this as a 4 byte string; if the first value is not zero, then we
#     866 # have extensions.
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/nifti1.py:850, in Nifti1Header.__init__(self, binaryblock, endianness, check, extensions)
#     849 """Initialize header from binary data block and extensions"""
# --> 850 super().__init__(binaryblock, endianness, check)
#     851 self.extensions = self.exts_klass(extensions)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/analyze.py:253, in AnalyzeHeader.__init__(self, binaryblock, endianness, check)
#     199 """Initialize header from binary data block
#     200
#     201 Parameters
#    (...)
#     251 True
#     252 """
# --> 253 super().__init__(binaryblock, endianness, check)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/wrapstruct.py:172, in WrapStruct.__init__(self, binaryblock, endianness, check)
#     171 if check:
# --> 172     self.check_fix()
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/wrapstruct.py:362, in WrapStruct.check_fix(self, logger, error_level)
#     361 for report in reports:
# --> 362     report.log_raise(logger, error_level)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/batteryrunners.py:271, in Report.log_raise(self, logger, error_level)
#     270 if self.error:
# --> 271     raise self.error(self.problem_msg)
#
# HeaderDataError: data code 26996 not recognized
#
# During handling of the above exception, another exception occurred:
#
# HeaderDataError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nii = se.load('example_nifti')
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:108, in load(fname, vox_size, return_type, sample_inds, loc_inds, field)
#     105     raise ValueError("Using both field and slicing currently not supported.")
#     107 if fname in datadict.keys():
# --> 108     data = _load_example(fname, datadict[fname], sample_inds, loc_inds, field)
#     109 else:
#     110     data = _load_from_path(fname, sample_inds, loc_inds, field)
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:165, in _load_example(fname, fileid, sample_inds, loc_inds, field)
#     163 try:
#     164     _download(fname, _load_stream(fileid[0]), fileid[1])
# --> 165     data = _load_from_cache(fname, fileid[1], sample_inds, loc_inds, field)
#     166 except ValueError as e:
#     167     print(e)
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:247, in _load_from_cache(fname, ftype, sample_inds, loc_inds, field)
#     245         return Model(**dd.io.load(fullpath))
#     246 elif ftype == 'nii':
# --> 247     return Nifti(fullpath)
#     248 elif ftype == 'locs':
#     249     return Location(fullpath)
#
# File ~/Documents/supereeg/supereeg/supereeg/nifti.py:53, in Nifti.__init__(self, data, affine, **kwargs)
#      51         data = load(data)
#      52     else:
# ---> 53         image = Nifti1Image.load(data)
#      54         super(Nifti, self).__init__(image.dataobj, image.affine)
#      56 if isinstance(data, np.ndarray):
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/dataobj_images.py:504, in DataobjImage.from_filename(klass, filename, mmap, keep_file_open)
#     502     raise ValueError("mmap should be one of {True, False, 'c', 'r'}")
#     503 file_map = klass.filespec_to_file_map(filename)
# --> 504 return klass.from_file_map(file_map, mmap=mmap, keep_file_open=keep_file_open)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/analyze.py:963, in AnalyzeImage.from_file_map(klass, file_map, mmap, keep_file_open)
#     961 hdr_fh, img_fh = klass._get_fileholders(file_map)
#     962 with hdr_fh.get_prepare_fileobj(mode='rb') as hdrf:
# --> 963     header = klass.header_class.from_fileobj(hdrf)
#     964 hdr_copy = header.copy()
#     965 imgf = img_fh.fileobj
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/nifti1.py:863, in Nifti1Header.from_fileobj(klass, fileobj, endianness, check)
#     860 @classmethod
#     861 def from_fileobj(klass, fileobj, endianness=None, check=True):
#     862     raw_str = fileobj.read(klass.template_dtype.itemsize)
# --> 863     hdr = klass(raw_str, endianness, check)
#     864     # Read next 4 bytes to see if we have extensions.  The nifti standard
#     865     # has this as a 4 byte string; if the first value is not zero, then we
#     866     # have extensions.
#     867     extension_status = fileobj.read(4)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/nifti1.py:850, in Nifti1Header.__init__(self, binaryblock, endianness, check, extensions)
#     848 def __init__(self, binaryblock=None, endianness=None, check=True, extensions=()):
#     849     """Initialize header from binary data block and extensions"""
# --> 850     super().__init__(binaryblock, endianness, check)
#     851     self.extensions = self.exts_klass(extensions)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/analyze.py:253, in AnalyzeHeader.__init__(self, binaryblock, endianness, check)
#     198 def __init__(self, binaryblock=None, endianness=None, check=True):
#     199     """Initialize header from binary data block
#     200
#     201     Parameters
#    (...)
#     251     True
#     252     """
# --> 253     super().__init__(binaryblock, endianness, check)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/wrapstruct.py:172, in WrapStruct.__init__(self, binaryblock, endianness, check)
#     170 self._structarr = wstr.copy()
#     171 if check:
# --> 172     self.check_fix()
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/wrapstruct.py:362, in WrapStruct.check_fix(self, logger, error_level)
#     360 self, reports = battrun.check_fix(self)
#     361 for report in reports:
# --> 362     report.log_raise(logger, error_level)
#
# File ~/Software/anaconda3/envs/supereeg/lib/python3.12/site-packages/nibabel/batteryrunners.py:271, in Report.log_raise(self, logger, error_level)
#     269 if self.problem_level and self.problem_level >= error_level:
#     270     if self.error:
# --> 271         raise self.error(self.problem_msg)
#
# HeaderDataError: data code 26996 not recognized

# %% [markdown]
# # Initialize nifti objects
#
# Nifti objects can be initialized by passing any of the following to the Nifti class instance initialization function: - A path to a nifti file (ending in .nii or .nii.gz) - An existing Nifti object (this makes a copy of the object) - A path to any other toolbox-supported datatype, or an instance of another supported datatype (Brain or Model objects)
#
# You may also initialize a Nifti object using the load function by specifying return_type='nii'.
#
# For example:

# %%
bo_nii = se.Nifti('example_data')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bo_nii = se.Nifti('example_data')
#
# File ~/Documents/supereeg/supereeg/supereeg/nifti.py:66, in Nifti.__init__(self, data, affine, **kwargs)
#      63     super(Nifti, self).__init__(data.dataobj, data.affine)
#      65 elif isinstance(data, Brain):
# ---> 66     data = data.to_nii(**kwargs)
#      67     super(Nifti, self).__init__(data.dataobj, data.affine)
#      69 elif isinstance(data, Model):
#
# File ~/Documents/supereeg/supereeg/supereeg/brain.py:609, in Brain.to_nii(self, filepath, template, vox_size, sample_rate)
#     605 if not np.array_equiv(temp_v_size, v_size):
#     606     warnings.warn('Voxel sizes of reconstruction and template do not match. '
#     607                   'Voxel sizes calculated from model locations.')
# --> 609 nifti = _brain_to_nifti(self, img)
#     611 if filepath:
#     612     nifti.to_filename(filepath)
#
# File ~/Documents/supereeg/supereeg/supereeg/helpers.py:1621, in _brain_to_nifti(bo, nii_template, antialiasing)
#    1618 else:
#    1619     shape = bo.nifti_shape
# -> 1621 data = np.zeros(tuple(list(shape) + [Y.shape[0]]))
#    1622 counts = np.zeros(data.shape)
#    1624 if antialiasing is True:
#
# MemoryError: Unable to allocate 33.6 GiB for an array with shape (91, 109, 91, 5000) and data type float64

# %% [markdown]
# Or:

# %%
bo_nii = se.load('example_data', return_type='nii')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bo_nii = se.load('example_data', return_type='nii')
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:112, in load(fname, vox_size, return_type, sample_inds, loc_inds, field)
#     110     data = _load_from_path(fname, sample_inds, loc_inds, field)
#     111 if field is None:
# --> 112     return _convert(data, return_type, vox_size)
#     113 else:
#     114     return data
#
# File ~/Documents/supereeg/supereeg/supereeg/load.py:130, in _convert(data, return_type, vox_size)
#     128 elif return_type == 'nii':
#     129     if type(data) is not Nifti:
# --> 130         data = Nifti(data)
#     131     if vox_size:
#     132         return _resample_nii(data, target_res=vox_size)
#
# File ~/Documents/supereeg/supereeg/supereeg/nifti.py:66, in Nifti.__init__(self, data, affine, **kwargs)
#      63     super(Nifti, self).__init__(data.dataobj, data.affine)
#      65 elif isinstance(data, Brain):
# ---> 66     data = data.to_nii(**kwargs)
#      67     super(Nifti, self).__init__(data.dataobj, data.affine)
#      69 elif isinstance(data, Model):
#
# File ~/Documents/supereeg/supereeg/supereeg/brain.py:609, in Brain.to_nii(self, filepath, template, vox_size, sample_rate)
#     605 if not np.array_equiv(temp_v_size, v_size):
#     606     warnings.warn('Voxel sizes of reconstruction and template do not match. '
#     607                   'Voxel sizes calculated from model locations.')
# --> 609 nifti = _brain_to_nifti(self, img)
#     611 if filepath:
#     612     nifti.to_filename(filepath)
#
# File ~/Documents/supereeg/supereeg/supereeg/helpers.py:1621, in _brain_to_nifti(bo, nii_template, antialiasing)
#    1618 else:
#    1619     shape = bo.nifti_shape
# -> 1621 data = np.zeros(tuple(list(shape) + [Y.shape[0]]))
#    1622 counts = np.zeros(data.shape)
#    1624 if antialiasing is True:
#
# MemoryError: Unable to allocate 33.6 GiB for an array with shape (91, 109, 91, 5000) and data type float64

# %% [markdown]
# # Spatial resampling
#
# Any Nifti object may be quickly resampled to an arbitrary voxel size using the vox_size argument. The voxel sizes may be specified either as a scalar (for cubic voxels) or as a 3D tuple (for rectangular prism or parallelopiped voxels):

# %%
bo_nii = se.Nifti('example_data', vox_size=6)

# %% [markdown]
# # Nifti object methods
#
# Some useful methods on a nifti object:

# %% [markdown]
# ## nifti.info()
#
# This method will give you a summary of the nifti object:

# %%
nii.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 nii.info()
#
# NameError: name 'nii' is not defined

# %% [markdown]
# ## nifti.get_slice()
#
# This method allows you to slice out images from your nifti object, and returns the indexed nifti.

# %%
nii_sliced = bo_nii.get_slice(index=[0,1,2])

# %% [markdown]
# ## nifti.plot_glass_brain()
#
# This method will plot your nifti object.
#
# This method wraps nilearn.plot_glass_brain to plot the nifti object, so any arguments that nilearn.plot_glass_brain accepts are supported by nifti.plot_glass_brain.

# %%
nii_sliced.plot_glass_brain()

# %% [markdown]
# ## nifti.plot_anat()
#
# This method will plot your nifti object.
#
# This method wraps nilearn.plot_anat to plot the nifti object, so any arguments that nilearn.plot_anat accepts are supported by nifti.anat. For example, you can plot the example nifti:

# %%
nii.plot_anat()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nii.plot_anat()
#
# NameError: name 'nii' is not defined

# %% [markdown]
# ## nifti.make_gif()
#
# This method will plot 4D nifti data as nilearn.plot_glass_brain, save as png files, and compile the files as gif.
#
# This method wraps nilearn.plot_glass_brain to plot the nifti object, so any arguments that nilearn.plot_glass_brain accepts are supported by nifti.plot_glass_brain.

# %%
#nii.make_gif(gifpath='/path/to/save/gif', index=range(0, 10), name=None, **kwargs)

# %% [markdown]
# ## nifti.save()
#
# This method will save your nifti object to the specified filepath location as a ‘nii’ file.

# %%
#nii.save(filepath='/path/to/save/nifti')
